# %% [markdown]
# GUIA 5 PLANNING
#
# Escalante Guadalupe - MAIE

# %%
# ejercicio 1
# Escriba un programa en Python que imprima en consola el recorrido de una lista
# cuyos valores son: mascotas=[“perro”,”gato”, “loro”]
mascotas=["perro", "gato", "loro"]

print("la primer mascota es: ", mascotas[0])

for mascota in mascotas[1:]:
    print("la siguiente mascota es: ", mascota)
print ("fin")
# Out:
# la primer mascota es:  perro
# la siguiente mascota es:  gato
# la siguiente mascota es:  loro
# fin

# %%
# ejercicio 2
# Utilice la librería os para listar todos los directorios dentro del directorio “/dev”

import os

solo_directorios = [ os.listdir("/dev") if os.path.isdir else ""]
n=1
for directorio in solo_directorios:
    for nombre in directorio:
     print("directorio" ,n, nombre)
     n=n+1
print("fin")
# Out:
# directorio 1 rfkill
# directorio 2 vga_arbiter
# directorio 3 mem
# directorio 4 null
# directorio 5 port
# directorio 6 zero
# directorio 7 full
# directorio 8 random
# directorio 9 urandom
# directorio 10 kmsg
# directorio 11 tty
# directorio 12 console
# directorio 13 tty0
# directorio 14 vcs
# directorio 15 vcsu
# directorio 16 vcsa
# directorio 17 vcs1
# directorio 18 vcsu1
# directorio 19 vcsa1
# directorio 20 tty1
# directorio 21 tty2
# directorio 22 tty3
# directorio 23 tty4
# directorio 24 tty5
# directorio 25 tty6
# directorio 26 tty7
# directorio 27 tty8
# directorio 28 tty9
# directorio 29 tty10
# directorio 30 tty11
# directorio 31 tty12
# directorio 32 tty13
# directorio 33 tty14
# directorio 34 tty15
# directorio 35 tty16
# directorio 36 tty17
# directorio 37 tty18
# directorio 38 tty19
# directorio 39 tty20
# directorio 40 tty21
# directorio 41 tty22
# directorio 42 tty23
# directorio 43 tty24
# directorio 44 tty25
# directorio 45 tty26
# directorio 46 tty27
# ...

# %%
# ejercicio 3
# Haga un programa en python donde tome dos valores de entrada: sueldo y rango.
# Con ello, calcule la asignación que percibirá el empleado, considerando la tabla



sueldo = int(input("Ingrese el sueldo: "))
rango = int(input("Ingrese el rango entre 1 y 3: "))

if rango == 1:
    resultado = round(sueldo * 0.83, 2)
elif rango == 2:
    resultado = round(sueldo * 1.2, 2)
else:
    resultado = round(sueldo * 5, 2)

print("El resultado es:", resultado)
# Out:
# El resultado es: 8.3

# %% [markdown]
# EJERCICIOS 4, 5, 6 Y 7 EN ARCHIVOS APARTE
